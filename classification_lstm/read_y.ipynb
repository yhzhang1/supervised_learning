# %%
import pandas as pd

variety = 'RB'
y_store = pd.HDFStore('/home/data/vb/training_y_reg_150.h5', mode='r')
y_series = y_store.get(variety)
y_series
# Out:
# start_time
# 2015-04-29 13:45:42.500   -0.042061
# 2015-04-29 13:46:23.500   -0.210305
# 2015-04-29 13:47:33.000   -0.168279
# 2015-04-29 13:48:47.500   -0.252419
# 2015-04-29 13:51:33.500   -0.210482
#                              ...
# 2018-03-29 14:24:33.500    0.288268
# 2018-03-29 14:32:16.500    0.144071
# 2018-03-29 14:39:03.000    0.028789
# 2018-03-29 14:41:07.000    0.374586
# 2018-03-29 14:43:37.500    0.316684
# Name: Y_logret, Length: 99419, dtype: float64

# %%
import seaborn as sns

sns.distplot(y_series)
